# %%
# !pip install mysql.connector
# Out:
# ...
#   Using cached mysql_connector-2.2.9-cp38-cp38-win_amd64.whl
# ...

# %%
import pandas as pd
import mysql.connector

# %%
pd.set_option('display.max_columns', None)

# %%
cnx = mysql.connector.connect(host = 'mysqlservernewjprod.mysql.database.azure.com', user = "phantom@mysqlservernewjprod", password = 'Zurich$1', db = 'fb', port = 3306)

# %%
cursor = cnx.cursor(buffered=True)

# %%
sql = 'SELECT * FROM fb.postinsightsdaily where pageName = "newjplus";'

df = pd.read_sql(sql, cnx)

df.to_csv('postinsightsdaily_24_12_2020.csv', index=False)

cursor.close()
# Out:
# True

# %%
data = pd.read_csv('postinsightsdaily_24_12_2020.csv')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 271946 entries, 0 to 271945
# Data columns (total 34 columns):
#  #   Column                                     Non-Null Count   Dtype
# ---  ------                                     --------------   -----
#  0   id                                         271946 non-null  object
#  1   videoId                                    271946 non-null  int64
#  2   pageId                                     271946 non-null  int64
#  3   pageName                                   271946 non-null  object
#  4   permalink_url                              271946 non-null  object
#  5   message                                    271946 non-null  object
#  6   post_created_time                          271946 non-null  object
#  7   post_created_time_zone                     271946 non-null  object
#  8   published_time_ist                         271946 non-null  object
#  9   post_video_views                           271946 non-null  int64
# ...

# %%
data.head()
# Out:
#                                      id          videoId            pageId  \
# 0  07cdf894-5c53-11ea-9de5-48682eb0e778  121907679248283  1954072204870360
# 1  07ce8f39-5c53-11ea-9de5-48682eb0e778  121907679248283  1954072204870360
# 2  07cf387b-5c53-11ea-9de5-48682eb0e778  121907679248283  1954072204870360
# 3  07cfc443-5c53-11ea-9de5-48682eb0e778  121907679248283  1954072204870360
# 4  07d04920-5c53-11ea-9de5-48682eb0e778  121907679248283  1954072204870360
#
#    pageName                                      permalink_url  \
# 0  newjplus  https://www.facebook.com/NEWJplus/videos/12190...
# 1  newjplus  https://www.facebook.com/NEWJplus/videos/12190...
# 2  newjplus  https://www.facebook.com/NEWJplus/videos/12190...
# 3  newjplus  https://www.facebook.com/NEWJplus/videos/12190...
# 4  newjplus  https://www.facebook.com/NEWJplus/videos/12190...
#
#                                              message    post_created_time  \
# ...

# %% [markdown]
# ### Create dataframe for turing consist of published_time_ist and message

# %%
data_for_turing = data.drop_duplicates('videoId', keep = 'first')

# %%
data_for_turing.shape
# Out:
# (6235, 34)

# %%
data_for_turing = data_for_turing[['message', 'published_time_ist']]

# %%
data_for_turing.reset_index(drop = True, inplace = True)

# %%
data_for_turing.to_csv('data_for_turing.csv', index = False)
